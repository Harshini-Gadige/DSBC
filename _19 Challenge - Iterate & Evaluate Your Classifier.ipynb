# %%
# %matplotlib inline
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
import string
import sklearn
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true;
function code_toggle() {
if (code_show){
$('div.input').hide();
} else {
$('div.input').show();
}
code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
The code for this notebook is hidden for easier reading.
To toggle it on/off, please click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
# if (code_show){
# $('div.input').hide();
# } else {
# $('div.input').show();
# }
# code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The code for this notebook is hidden for easier reading.
# To toggle it on/off, please click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# # Amazon

# %%
path = ("C:\\Users\\beri.e.ndifon\\Documents\\Everything Else\\Personal\\Thinkful\\CSV Datasets\\Unit 2\\Unit 2 Lesson 2\\Naive Bayes Sentiment Analysis\\amazon_labelled.txt")
amazon = pd.read_csv(path, delimiter= '\t', header=None)
amazon.columns = ['review', 'sentiment']

# %%
amazon.head()
# Out:
#                                               review  sentiment
# 0  So there is no way for me to plug it in here i...          0
# 1                        Good case, Excellent value.          1
# 2                             Great for the jawbone.          1
# 3  Tied to charger for conversations lasting more...          0
# 4                                  The mic is great.          1

# %%
amazon_positive = amazon[amazon['sentiment']==1]
amazon_negative = amazon[amazon['sentiment']==0]

# %%
positive_features = list(amazon_positive['review'].str.split())
positive_features = [item for sublist in positive_features for item in sublist]
positive_features = [''.join(c for c in s if c not in string.punctuation) for s in positive_features]
positive_features = [s for s in positive_features if s]
positive_features = list(map(lambda x:x.lower(),positive_features))
positive_features = Counter(positive_features)

negative_features = list(amazon_negative['review'].str.split())
negative_features = [item for sublist in negative_features for item in sublist]
negative_features = [''.join(c for c in s if c not in string.punctuation) for s in negative_features]
negative_features = [s for s in negative_features if s]
negative_features = list(map(lambda x:x.lower(),negative_features))
negative_features = Counter(negative_features)

# %%
print(positive_features)
# Out:
# Counter({'the': 237, 'and': 188, 'i': 154, 'is': 141, 'it': 128, 'this': 105, 'a': 105, 'great': 92, 'to': 86, 'phone': 86, 'my': 72, 'very': 69, 'for': 66, 'with': 65, 'good': 62, 'of': 49, 'works': 46, 'on': 44, 'have': 38, 'was': 36, 'in': 34, 'product': 33, 'that': 32, 'quality': 31, 'well': 31, 'headset': 31, 'sound': 27, 'excellent': 26, 'so': 26, 'price': 25, 'has': 24, 'its': 24, 'one': 23, 'are': 22, 'battery': 22, 'nice': 22, 'you': 21, 'use': 21, 'best': 21, 'had': 21, 'but': 21, 'recommend': 20, 'as': 20, 'all': 20, 'love': 20, 'ive': 19, 'than': 19, 'case': 18, 'like': 18, 'would': 17, 'from': 16, 'ear': 16, 'any': 15, 'not': 15, 'really': 15, 'comfortable': 14, 'easy': 14, 'your': 14, 'happy': 13, 'these': 13, 'new': 12, 'up': 12, 'fine': 12, 'bluetooth': 12, 'just': 12, 'been': 12, 'no': 12, 'better': 12, 'im': 12, 'am': 12, 'can': 11, 'car': 11, 'even': 11, 'time': 11, 'also': 11, 'be': 11, 'far': 10, 'clear': 10, 'device': 10, 'worked': 10, '2': 10, 'cell': 10, 'fits': 10, 'an': 10, 'camera': 9, 
tones': 3, 'belt': 3, 'day': 3, 'could': 3, 'mic': 2, 'he': 2, 'going': 2, 'extended': 2, 'though': 2, 'who': 2, 'fire': 2, 'yet': 2, 'run': 2, 'three': 2, 'charging': 2, 'pocket': 2, 'owned': 2, 'mobile': 2, 'never': 2, 'protection': 2, 'actually': 2, 'pda': 2, 'dropped': 2, '510': 2, 'headphones': 2, 'last': 2, 'seriously': 2, 'glasses': 2, 'way': 2, 'choice': 2, 'docking': 2, 'station': 2, 'home': 2, 'handy': 2, 'everyone': 2, 'loves': 2, 'cheaper': 2, 'super': 2, 'ease': 2, 'black': 2, 'piece': 2, 'wife': 2, 'ask': 2 ...

# %%
print(negative_features)
# Out:
# Counter({'the': 276, 'i': 162, 'it': 153, 'and': 122, 'a': 113, 'to': 110, 'is': 102, 'not': 102, 'this': 101, 'phone': 76, 'my': 71, 'of': 70, 'for': 55, 'in': 54, 'was': 54, 'that': 48, 'you': 47, 'with': 47, 'on': 45, 'have': 35, 'very': 34, 'had': 27, 'dont': 26, 'as': 25, 'but': 25, 'work': 25, 'if': 24, 'battery': 23, 'product': 22, 'all': 21, 'after': 21, 'me': 20, 'are': 20, 'use': 20, 'ear': 19, 'does': 19, 'its': 19, 'money': 18, 'your': 18, 'quality': 18, 'one': 17, 'from': 17, 'would': 17, 'out': 17, 'only': 17, 'so': 16, 'time': 16, 'headset': 16, 'at': 16, 'be': 16, 'or': 15, 'then': 15, 'do': 15, 'first': 15, 'poor': 15, 'service': 15, 'when': 15, 'no': 14, 'get': 14, 'up': 14, 'what': 14, 'waste': 14, 'sound': 14, 'doesnt': 14, 'buy': 14, 'bad': 14, 'worst': 14, 'could': 13, 'good': 13, 'too': 13, 'ever': 13, 'charger': 12, 'like': 12, 'off': 12, 'im': 12, 'will': 12, 'more': 11, 'calls': 11, '2': 11, 'about': 11, 'case': 11, 'really': 11, 'also': 11, 'same': 11, 'piece': 11, 'hear': 10, 'charge': 10, 'disappointed': 10, 'enough': 10, 'item': 10, 'worked': 10, 'thing': 10, 'did': 10, 'still': 10, 'terrible': 10, 'has': 10, 'there': 9, 'plug': 9, 'than': 9, 'bought': 9, 'few': 9, 'which': 9, 'an': 9, 'just': 9, 'ive': 9, 'now': 9, 'while': 9, 'because': 9, 'volume': 8, 'two': 8, 'design': 8, 'problem': 8, 'can': 8, 'broke': 8, 'new': 8, 'am': 8, 'make': 8, 'horrible': 8, 'used': 8, 'customer': 8, 'junk': 8, 'they': 8, 'unit': 8, 'by': 7, 'right': 7, 'them': 7, 'how': 7, 'didnt': 7, 'talk': 7, 'car': 7, 'even': 7, 'better': 7, 'well': 7, 'these': 7, 'over': 7, 'useless': 7, 'back': 7, 'however': 7, 'problems': 6, '5': 6, 'into': 6, 'makes': 6, 'last': 6, 'went': 6, 'think': 6, 'couldnt': 6, 'phones': 6, 'days': 6, 'buttons': 6, 'months': 6, 'completely': 6, 'reception': 6, 'stay': 6, 'fit': 6, 'call': 6, 'company': 6, 'looks': 6, 'never': 6, 'recommend': 6, 'purchase': 6, 'cant': 6, 'made': 6, 'difficult': 6, 'cheap': 6, 'way': 5, 'long': 5, 'again': 5, 'life': 5, 'dropped': 5, 'we': 5, 'other': 5, 'big': 5, 'week': 5, 'within': 5, 'down': 5, 'great': 5, 'much': 5, 'motorola': 5, 'using': 5, 'signal': 5, 'put': 5, 'some': 5, 'disappointment': 5, 'bluetooth': 5, 'return': 5, 'old': 5, 'nokia': 5, 'want': 5, 'anything': 5, 'disappointing': 5, 'any': 5, 'crap': 5, 'picture': 5, 'low': 5, 'anyone': 5, 'none': 5, 'easily': 5, 'take': 5, 'started': 4, 'instructions': 4, 'people': 4, 'hate': 4, '3': 4, 'turn': 4, 'impressed': 4, 'audio': 4, 'their': 4, 'verizon': 4, 'loud': 4, 'support': 4, 'player': 4, 'later': 4, 'headsets': 4, 'got': 4, 'cell': 4, 'hours': 4, 'screen': 4, 'black': 4, 'headphones': 4, 'where': 4, 'before': 4, 'being': 4, 'kind': 4, 'year': 4, 'mistake': 4, 'unreliable': 4, 'buying': 4, 'weak': 4, 'amazon': 4, 'sucks': 4, '1': 4, 'going': 4, 'having': 4, 'looking': 4, 'plastic': 4, 'nothing': 4, 'software': 4, 'unfortunately': 4, 'real': 4, 'cannot': 4, 'look': 4, 'since': 4, 'go': 3, 'conversations': 3, 'several': 3, 'sending': 3, 'were': 3, 'clip': 3, 'comfortable': 3, 'place': 3, 'most': 3, 'hold': 3, 'little': 3, 'left': 3, 'worthless': 3, 'should': 3, 'different': 3, 'longer': 3, 'expect': 3, 'far': 3, 'received': 3, 'match': 3, 'camera': 3, 'around': 3, 'end': 3, 'may': 3, 'failed': 3, 'coverage': 3, 'area': 3, 'bars': 3, 'internet': 3, 'less': 3, 'obviously': 3, 'side': 3, 'slow': 3, 'every': 3, 'once': 3, 'device': 3, 'minutes': 3, 'voice': 3, 'lost': 3, 'weeks': 3, 'lasts': 3, 'id': 3, 'experience': 3, 'cable': 3, 'either': 3, 'drain': 3, 'earpiece': 3, 'poorly': 3, 'care': 3, 'uncomfortable': 3, 'quite': 3, 'plugged': 3, 'face': 3, 'keep': 3, 'comes': 3, 'goes': 3, 'dead': 3, 'couple': 3, 'been': 3, 'easy': 3, 'rather': 3, 'away': 3, 'find': 3, 'might': 3, 'small': 3, 'turned': 3, 'always': 3, 'know': 3, 'important': 3, 'feature': 3, 'hard': 3, 'times': 3, 'refund': 3, 'drop': 3, 'sprint': 3, 'charging': 3, 'extra': 3, 'store': 3, 'pay': 3, 'awful': 3, 'tinny': 3, 'three': 3, 'tried': 3, 'kep ...

# %% [markdown]
# ### I chose features that seemed generic enough to apply to classifying positive and negative Amazon review sentiment across product categories, yet specific enough that Bayesian poisoning due to interpretation issues such as sarcasm would be limited.

# %%
positives = ['amazing', 'best','comfortable', 'easy', 'excellent', 'fabulous', 'fantastic', 'good', 'great', 'happy', 'impressed', 'love', 'loved', 'nice', 'perfectly', 'satisfied','works','worked']
negatives = ['bad', 'beware', 'crap', 'crappy', 'difficult', 'disappointed', 'disappointing', 'hate', 'hated', 'horrible', 'junk', 'not', 'problem', 'return', 'sucks', 'useless', 'waste', 'worst']
for positive in positives:
    amazon[str(positive)] = amazon.review.str.contains(str(positive),case=False)
for negative in negatives:
    amazon[str(negative)] = amazon.review.str.contains(str(negative),case=False)
amazon['sentiment'] = (amazon['sentiment'] == 1)

# %%
amazon.head()
# Out:
#                                               review  sentiment  amazing  \
# 0  So there is no way for me to plug it in here i...      False    False
# 1                        Good case, Excellent value.       True    False
# 2                             Great for the jawbone.       True    False
# 3  Tied to charger for conversations lasting more...      False    False
# 4                                  The mic is great.       True    False
#
#     best  comfortable   easy  excellent  fabulous  fantastic   good  ...    \
# 0  False        False  False      False     False      False  False  ...
# 1  False        False  False       True     False      False   True  ...
# 2  False        False  False      False     False      False  False  ...
# 3  False        False  False      False     False      False  False  ...
# 4  False        False  False      False     False      False  False  ...
#
#    hated  horrible   junk    not  problem  return  sucks  useless  waste  \
# 0  False     False  False  False    False   False  False    False  False
# 1  False     False  False  False    False   False  False    False  False
# 2  False     False  False  False    False   False  False    False  False
# 3  False     False  False  False     True   False  False    False  False
# 4  False     False  False  False    False   False  False    False  False
#
#    worst
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 38 columns]

# %%
plt.figure(figsize=[15,15])
correlations_amazon = sns.heatmap(amazon.corr(),square=True)

# %% [markdown]
# ### There are some inter-feature correlations, but none so significant that the independence assumption would force me to drop one or both of them.

# %%
data_amazon = amazon.loc[:,'amazing':'worst']
target_amazon = amazon['sentiment']

bnb = BernoulliNB()
bnb.fit(data_amazon, target_amazon)
y_pred_amazon = bnb.predict(data_amazon)
print("Number of mislabeled points out of a total {} points : {}.".format(data_amazon.shape[0],(target_amazon != y_pred_amazon).sum()))
# Out:
# Number of mislabeled points out of a total 1000 points : 230.

# %% [markdown]
# ## In-Sample Evaluation: Holdout Groups - Amazon

# %%
X = data_amazon
y = target_amazon

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
bnb.fit(X_train,y_train)
y_pred_class = bnb.predict(X_test)
print("Classification Accuracy (Percentage of Correct Predictions): {:.2%}.".format(metrics.accuracy_score(y_test,y_pred_class)))
# Out:
# Classification Accuracy (Percentage of Correct Predictions): 76.00%.

# %% [markdown]
# ## In-Sample Evaluation: Repeated k-Fold Cross-Validation - Amazon

# %%
def iterative_xv(X,y):
    features = positives + negatives
    for i in range(5):
        print("Iteration {}".format(i+1))
        scores = []
        for feature in features:
            current_X = X.drop(feature, axis=1)
            print("Model Modification: Removed '{}'.".format(feature))
            score = cross_val_score(bnb, current_X, y, cv=10, scoring='accuracy').mean()
            scores.append(score)
            print("Out-of-Sample Accuracy (Averaged Across Folds): {:.2f}%.".format(score*100))
        index_to_drop = np.argmin(scores)
        feature_to_drop = features[index_to_drop]
        features.remove(feature_to_drop)
        X = X.drop(feature_to_drop, axis=1)
    return None

# %%
X = data_amazon
y = target_amazon
iterative_xv(X,y)
# Out:
# Iteration 1
# Model Modification: Removed 'amazing'.
# Out-of-Sample Accuracy (Averaged Across Folds): 76.50%.
# Model Modification: Removed 'best'.
# Out-of-Sample Accuracy (Averaged Across Folds): 75.00%.
# Model Modification: Removed 'comfortable'.
# Out-of-Sample Accuracy (Averaged Across Folds): 75.80%.
# Model Modification: Removed 'easy'.
# Out-of-Sample Accuracy (Averaged Across Folds):
'.
# Out-of-Sample Accuracy (Averaged Across Folds): 68.30%.
# Model Modification: Removed 'disappointing'.
# Out-of-Sample Accuracy (Averaged Across Folds): 66.70%.
# Model Modification: Removed 'hated'.
# Out-of-Sample Accuracy (Averaged Across Folds): 66.70%.
# Model Modification: Removed 'horrible'.
# Out-of-Sample Accuracy (Averaged Across Folds): 66.90%.
# Model Modification: Removed 'junk'.
# Out-of-Sample Accuracy (Averaged Across Folds): 67.50%.
# Model Modification: Removed 'not'.
# Out-of-Sample Accuracy (Averaged Across Folds): 68.10%.
# Model Modification: Removed 'problem'.
# Out-of-Sample Accuracy (Averaged Across Folds): 67.00%.
# Model Modification: Removed 'return'.
# Out-of-Sample Accuracy (Averaged Across Folds): 67.50%.
# Model Modification: Removed 'sucks'.
# Out-of-Sample Accuracy (Averaged Across Folds): 66.80%.
# Model Modification: Removed 'useless'.
# Out-of-Sample Accuracy (Averaged Across Folds): 67.00%.
# Model Modification: Removed 'waste'.
# Out-of-Sample Accuracy (Averaged Across Folds): 69.20%.
# Model Modification: Removed 'worst'.
# Out-of-Sample Accuracy (Averaged Across Folds): 69.20%.

# %% [markdown]
# # Yelp

# %%
new_path = 'C:\\Users\\beri.e.ndifon\\Documents\\Everything Else\\Personal\\Thinkful\\CSV Datasets\\Unit 2\\Unit 2 Lesson 2\\Naive Bayes Sentiment Analysis\\yelp_labelled.txt'
yelp = pd.read_csv(new_path, delimiter= '\t', header=None)
yelp.columns = ['review', 'sentiment']

# %%
yelp.head()
# Out:
#                                               review  sentiment
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
for positive in positives:
    yelp[str(positive)] = yelp.review.str.contains(str(positive),case=False)
for negative in negatives:
    yelp[str(negative)] = yelp.review.str.contains(str(negative),case=False)
yelp['sentiment'] = (yelp['sentiment'] == 1)

# %%
data_yelp = yelp.loc[:,'amazing':'worst']
target_yelp = yelp['sentiment']

bnb = BernoulliNB()
bnb.fit(data_yelp, target_yelp)
y_pred_yelp = bnb.predict(data_yelp)
print("Number of mislabeled points out of a total {} points : {}.".format(data_yelp.shape[0],(target_yelp != y_pred_yelp).sum()))
# Out:
# Number of mislabeled points out of a total 1000 points : 283.

# %%
yelp.head()
# Out:
#                                               review  sentiment  amazing  \
# 0                           Wow... Loved this place.       True    False
# 1                                 Crust is not good.      False    False
# 2          Not tasty and the texture was just nasty.      False    False
# 3  Stopped by during the late May bank holiday of...       True    False
# 4  The selection on the menu was great and so wer...       True    False
#
#     best  comfortable   easy  excellent  fabulous  fantastic   good  ...    \
# 0  False        False  False      False     False      False  False  ...
# 1  False        False  False      False     False      False   True  ...
# 2  False        False  False      False     False      False  False  ...
# 3  False        False  False      False     False      False  False  ...
# 4  False        False  False      False     False      False  False  ...
#
#    hated  horrible   junk    not  problem  return  sucks  useless  waste  \
# 0  False     False  False  False    False   False  False    False  False
# 1  False     False  False   True    False   False  False    False  False
# 2  False     False  False   True    False   False  False    False  False
# 3  False     False  False  False    False   False  False    False  False
# 4  False     False  False  False    False   False  False    False  False
#
#    worst
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 38 columns]

# %%
plt.figure(figsize=[15,15])
correlations_yelp = sns.heatmap(yelp.corr(),square=True)

# %% [markdown]
# ### Some of the features from the first context don't translate well here: 'bad','beware','crap','crappy', 'difficult', 'junk', and 'useless'.

# %% [markdown]
# ## In-Sample Evaluation: Holdout Groups - Yelp

# %%
X = data_yelp
y = target_yelp

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
bnb.fit(X_train,y_train)
y_pred_class = bnb.predict(X_test)
print("Classification Accuracy (Percentage of Correct Predictions): {:.2%}.".format(metrics.accuracy_score(y_test,y_pred_class)))
# Out:
# Classification Accuracy (Percentage of Correct Predictions): 65.60%.

# %% [markdown]
# ## In-Sample Evaluation:  Cross-Validation - Yelp

# %%
X = data_yelp
y = target_yelp
iterative_xv(X,y)
# Out:
# Iteration 1
# Model Modification: Removed 'amazing'.
# Out-of-Sample Accuracy (Averaged Across Folds): 69.70%.
# Model Modification: Removed 'best'.
# Out-of-Sample Accuracy (Averaged Across Folds): 70.60%.
# Model Modification: Removed 'comfortable'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.30%.
# Model Modification: Removed 'easy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'excellent'.
# Out-of-Sample Accuracy (Averaged Across Folds): 70.70%.
# Model Modification: Removed 'fabulous'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'fantastic'.
# Out-of-Sample Accuracy (Averaged Across Folds): 70.30%.
# Model Modification: Removed 'good'.
# Out-of-Sample Accuracy (Averaged Across Folds): 66.20%.
# Model Modification: Removed 'great'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'happy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 70.80%.
# Model Modification: Removed 'impressed'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'love'.
# Out-of-Sample Accuracy (Averaged Across Folds): 70.70%.
# Model Modification: Removed 'loved'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'nice'.
# Out-of-Sample Accuracy (Averaged Across Folds): 69.70%.
# Model Modification: Removed 'perfectly'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.40%.
# Model Modification: Removed 'satisfied'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'works'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'worked'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'bad'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.30%.
# Model Modification: Removed 'beware'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'crap'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'crappy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'difficult'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'disappointed'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'disappointing'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'hate'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'hated'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'horrible'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'junk'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'not'.
# Out-of-Sample Accuracy (Averaged Across Folds): 70.70%.
# Model Modification: Removed 'problem'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'return'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'sucks'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'useless'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'waste'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.50%.
# Model Modification: Removed 'worst'.
# Out-of-Sample Accuracy (Averaged Across Folds): 71.60%.
# Iteration 2
# Model Modification: Removed 'amazing'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'best'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'comfortable'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 'easy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'excellent'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'fabulous'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'fantastic'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'good'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'happy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'impressed'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.40%.
# Model Modification: Removed 'love'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.40%.
# Model Modification: Removed 'loved'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'nice'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'perfectly'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 'satisfied'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'works'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'worked'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'bad'.
# Out-of-Sample Accuracy (Averaged Across Folds): 66.00%.
# Model Modification: Removed 'beware'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'crap'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'crappy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'difficult'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'disappointed'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'disappointing'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'hate'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'hated'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'horrible'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.40%.
# Model Modification: Removed 'junk'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'not'.
# Out-of-Sample Accuracy (Averaged Across Folds): 65.40%.
# Model Modification: Removed 'problem'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'return'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.80%.
# Model Modification: Removed 'sucks'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'useless'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.90%.
# Model Modification: Removed 'waste'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'worst'.
# Out-of-Sample Accuracy (Averaged Across Folds): 66.30%.
# Iteration 3
# Model Modification: Removed 'amazing'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'best'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'easy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 'excellent'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'fabulous'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 'fantastic'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'good'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'happy'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'impressed'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'love'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.40%.
# Model Modification: Removed 'loved'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.30%.
# Model Modification: Removed 'nice'.
# Out-of-Sample Accuracy (Averaged Across Folds): 64.20%.
# Model Modification: Removed 'perfectly'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.60%.
# Model Modification: Removed 'satisfied'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 'works'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 'worked'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 'bad'.
# Out-of-Sample Accuracy (Averaged Across Folds): 65.80%.
# Model Modification: Removed 'beware'.
# Out-of-Sample Accuracy (Averaged Across Folds): 63.70%.
# Model Modification: Removed 