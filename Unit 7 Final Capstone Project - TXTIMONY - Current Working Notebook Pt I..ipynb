# %% [markdown]
# # Import Statements

# %%
from bs4 import BeautifulSoup
from sklearn.decomposition import TruncatedSVD, LatentDirichletAllocation, NMF
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
import itertools
import pandas as pd
import requests
import time
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Source Selection

# %% [markdown]
# ## API Query Outcome

# %%
acled = pd.read_csv('C:\\Users\\missn\\Documents\\Thinkful\\CSV Datasets\\Unit 7 Capstone Project\\2017-09-01-2018-09-01-Cameroon-Nigeria.csv')

# %%
acled.source.value_counts()
# Out:
# Vanguard (Lagos)                                                           506
# The Sun (Nigeria)                                                          191
# The Nation (Nigeria)                                                       113
# L'Oeil du Sahel                                                            109
# Daily Independent (Nigeria)                                                106
# The Guardian (Lagos)                                                        87
# This Day (Lagos)                                                            87
# Local Source Project                                                        85
# Local sources                                                               75
# Agence France Presse                                                        72
# Nigerian Tribune                                                            56
# Camer.be                                                                    52
# Daily Trust (Abuja)                                                         46
# Journal du Cameroun                                                         45
# Premium Times (Abuja)                                                       42
# Weekly Trust                                                                38
# PM News                                                                     38
# Nigeria Punch                                                               36
# Premium Times                                                               35
# Vanguard                                                                    32
# Bareta News                                                                 30
# Cameroon POSTline                                                           24
# Sahara Reporters                                                            22
# AFP                                                                         21
# Xinhua                                                                      21
# The Guardian                                                                19
# Leadership (Abuja)                                                          17
# Vanguard (Lagos); Nigeria Punch; Associated Press; Agence France Presse     16
# Vanguard (Lagos); The Nation (Nigeria)                                      15
# Associated Press                                                            14
#                                                                           ...
# Agence France Presse; Vanguard; Twitter                                      1
# This Day (Lagos); The Sun (Nigeria); Vanguard (Lagos)                        1
# Vanguard (Lagos); The Sun                                                    1
# New Telegraph                                                                1
# Telegram messaging service in Arabic 2128 gmt 30 Jan                         1
# PM News; The Sun                                                             1
# Vanguard (Lagos); Nnamdi Obasi Twitter Feed 09 March                         1
# Premium Times (Abuja); This Day (Lagos)                                      1
# Vanguard (Nigeria); The Nation (Nigeria)                                     1
# The Sun (Nigeria); Nigeria Watch                                             1
# Vanguard (Lagos); Nnamdi Obasi Twitter page, 23/02/2017                      1
# PM News; The Sun (Nigeria)                                                   1
# The Guardian; The Daily Independent                                          1
# Amaq; AFP                                                                    1
# Vanguard (Lagos); Daily Independent                                          1
# Agence France Presse; Xinhua                                                 1
# Twitter Source; Journal du Cameroun                                          1
# This Day (Lagos); Local Source Project                                       1
# Vanguard (Lagos); Agence France Presse; The Sun (Nigeria)                    1
# Daily Trust (Abuja); Agence France Presse; Vanguard                          1
# L'oeil du Sahel                                                              1
# Agence France Presse; The Sun; Xinhua; The Guardian                          1
# Daily Trust (Abuja); The Guardian (Lagos)                                    1
# Vanguard (Lagos); Guardian                                                   1
# Daily Independent (Nigeria); The Sun (Nigeria)                               1
# Xinhua; Vanguard; The Guardian; Agence France Presse                         1
# Agence France Presse; Nnamdi Obasi Twitter Feed 09 March                     1
# Nigeria Tribune                                                              1
# The Sun (Nigeria); This Day (Lagos)                                          1
# Garda World                                                                  1
# Name: source, Length: 153, dtype: int64

# %% [markdown]
# **Selections:**
# - https://www.vanguardngr.com | <span class="girk">Worked</span>
# - http://sunnewsonline.com/ | <span class="girk">Worked</span>
# - http://thenationonlineng.net/
# - https://independent.ng/ | <span class="girk">Worked</span>
# - https://www.afp.com/en | <span class="burk">Didn't Work</span>
# - https://www.tribuneonlineng.com/ | <span class="girk">Worked</span>
# - https://www.dailytrust.com.ng/ | <span class="girk">Worked</span>
# - https://www.journalducameroun.com/ | <span class="burk">Didn't Work</span>
# - https://www.premiumtimesng.com/ | <span class="burk">Didn't Work</span>
# - https://www.bareta.news/ | <span class="girk">Worked</span>
# - http://www.cameroonpostline.com/ | <span class="girk">Worked</span>
# - http://saharareporters.com/ | <span class="burk">Didn't Work</span>

# %% [markdown]
# # Site Scraping, Soup Making, & Corpus Creation

# %% [markdown]
# ## Site Scraping

# %% [markdown]
# ### Lightweight Ruby Web Service

# %%
path_or_buf = 'C:\\Users\\missn\\Documents\\Thinkful\\Python Notebooks\\2 Bootcamp\\links_json.js'
output = pd.read_json(path_or_buf)
output = output['links'].apply(pd.Series).rename(columns={'searchTerm': 'Search Term', 'site': 'Site', 'link': 'Link', 'url': 'URL'}).drop(['URL'], axis=1)
output = output[['Search Term', 'Site', 'Link']].dropna()

# %%
output
# Out:
#     Search Term           Site  \
# 0     Ambazonia       Vanguard
# 1     Ambazonia       Vanguard
# 2     Ambazonia       Vanguard
# 3     Ambazonia       Vanguard
# 4     Ambazonia       Vanguard
# 5     Ambazonia       Vanguard
# 6     Ambazonia       Vanguard
# 7     Ambazonia       Vanguard
# 8     Ambazonia       Vanguard
# 9     Ambazonia       Vanguard
# 10    Ambazonia       Vanguard
# 11    Ambazonia       Vanguard
# 12    Ambazonia       Vanguard
# 13    Ambazonia       Vanguard
# 14    Ambazonia       Vanguard
# 15    Ambazonia       Vanguard
# 16    Ambazonia       Vanguard
# 17    Ambazonia       Vanguard
# 18    Ambazonia       Vanguard
# 19    Ambazonia       Vanguard
# 23   Boko Haram       Vanguard
# 24   Boko Haram       Vanguard
# 25   Boko Haram       Vanguard
# 26   Boko Haram       Vanguard
# 27   Boko Haram       Vanguard
# 28   Boko Haram       Vanguard
# 29   Boko Haram       Vanguard
# 30   Boko Haram       Vanguard
# 31   Boko Haram       Vanguard
# 32   Boko Haram       Vanguard
# ..          ...            ...
# 278   Ambazonia  Cameroon Post
# 279   Ambazonia  Cameroon Post
# 280   Ambazonia  Cameroon Post
# 281   Ambazonia  Cameroon Post
# 282   Ambazonia  Cameroon Post
# 283   Ambazonia  Cameroon Post
# 284   Ambazonia  Cameroon Post
# 285   Ambazonia  Cameroon Post
# 286   Ambazonia  Cameroon Post
# 287   Ambazonia  Cameroon Post
# 288  Boko Haram  Cameroon Post
# 289  Boko Haram  Cameroon Post
# 290  Boko Haram  Cameroon Post
# 291  Boko Haram  Cameroon Post
# 292  Boko Haram  Cameroon Post
# 293  Boko Haram  Cameroon Post
# 294  Boko Haram  Cameroon Post
# 295  Boko Haram  Cameroon Post
# 296  Boko Haram  Cameroon Post
# 297  Boko Haram  Cameroon Post
# 298  Boko Haram  Cameroon Post
# 299  Boko Haram  Cameroon Post
# 300  Boko Haram  Cameroon Post
# 298  https://cameroonpostline.com/appointing-atanga...
# 299  https://cameroonpostline.com/appointing-atanga...
# 300  https://cameroonpostline.com/released-scnc-fir...
# 301  https://cameroonpostline.com/released-scnc-fir...
# 302  https://cameroonpostline.com/as-parliament-ope...
# 303  https://cameroonpostline.com/as-parliament-ope...
# 304  https://cameroonpostline.com/fame-ndongo-stoke...
# 305  https://cameroonpostline.com/fame-ndongo-stoke...
# 306  https://cameroonpostline.com/i-predicted-the-a...
# 307  https://cameroonpostline.com/i-predicted-the-a...
#
# [290 rows x 3 columns]

# %%
output['Link'].duplicated()
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
# 5       True
# 6      False
# 7       True
# 8      False
# 9       True
# 10     False
# 11      True
# 12     False
# 13      True
# 14     False
# 15      True
# 16     False
# 17      True
# 18     False
# 19      True
# 23     False
# 24      True
# 25     False
# 26      True
# 27     False
# 28      True
# 29     False
# 30      True
# 31     False
# 32      True
#        ...
# 278    False
# 279    False
# 280    False
# 281    False
# 282    False
# 283    False
# 284    False
# 285    False
# 286    False
# 287    False
# 288    False
# 289    False
# 290    False
# 291    False
# 292    False
# 293    False
# 294    False
# 295    False
# 296    False
# 297    False
# 298    False
# 299    False
# 300    False
# 301    False
# 302    False
# 303    False
# 304    False
# 305    False
# 306    False
# 307    False
# Name: Link, Length: 290, dtype: bool

# %%
output.loc[output.duplicated(), :].count()
# Out:
# Search Term    62
# Site           62
# Link           62
# dtype: int64

# %%
output_clean = output.drop_duplicates()

# %%
indexes = output_clean[output_clean['Link'].str.contains('#respond')].index.tolist()
output_clean = output_clean.drop(indexes, axis = 0)

# %%
print(indexes)
# Out:
# [269, 271, 273, 275, 277, 279, 281, 283, 285, 287, 289, 291, 293, 295, 297, 299, 301, 303, 305, 307]

# %%
output_clean
# Out:
#     Search Term           Site  \
# 0     Ambazonia       Vanguard
# 2     Ambazonia       Vanguard
# 4     Ambazonia       Vanguard
# 6     Ambazonia       Vanguard
# 8     Ambazonia       Vanguard
# 10    Ambazonia       Vanguard
# 12    Ambazonia       Vanguard
# 14    Ambazonia       Vanguard
# 16    Ambazonia       Vanguard
# 18    Ambazonia       Vanguard
# 23   Boko Haram       Vanguard
# 25   Boko Haram       Vanguard
# 27   Boko Haram       Vanguard
# 29   Boko Haram       Vanguard
# 31   Boko Haram       Vanguard
# 33   Boko Haram       Vanguard
# 35   Boko Haram       Vanguard
# 37   Boko Haram       Vanguard
# 39   Boko Haram       Vanguard
# 41   Boko Haram       Vanguard
# 46    Ambazonia       Sun News
# 47    Ambazonia       Sun News
# 48    Ambazonia       Sun News
# 49    Ambazonia       Sun News
# 50    Ambazonia       Sun News
# 51    Ambazonia       Sun News
# 52    Ambazonia       Sun News
# 53    Ambazonia       Sun News
# 54    Ambazonia       Sun News
# 55    Ambazonia       Sun News
# ..          ...            ...
# 258   Ambazonia    Bareta News
# 259   Ambazonia    Bareta News
# 260   Ambazonia    Bareta News
# 261  Boko Haram    Bareta News
# 262  Boko Haram    Bareta News
# 263  Boko Haram    Bareta News
# 264  Boko Haram    Bareta News
# 265  Boko Haram    Bareta News
# 266  Boko Haram    Bareta News
# 267  Boko Haram    Bareta News
# 268   Ambazonia  Cameroon Post
# 270  https://cameroonpostline.com/2018-presidential...
# 272  https://cameroonpostline.com/court-slams-ambaz...
# 274  https://cameroonpostline.com/biyas-secret-envo...
# 276  https://cameroonpostline.com/fon-muketes-palac...
# 278  https://cameroonpostline.com/amba-boys-cleanse...
# 280  https://cameroonpostline.com/am-i-a-francophon...
# 282  https://cameroonpostline.com/gunmen-hide-trave...
# 284  https://cameroonpostline.com/anglophone-crisis...
# 286  https://cameroonpostline.com/gunmen-block-govt...
# 288  https://cameroonpostline.com/cameroon-human-ri...
# 290  https://cameroonpostline.com/bir-spread-tracts...
# 292  https://cameroonpostline.com/defence-minister-...
# 294  https://cameroonpostline.com/govt-announces-12...
# 296  https://cameroonpostline.com/biya-calls-for-po...
# 298  https://cameroonpostline.com/appointing-atanga...
# 300  https://cameroonpostline.com/released-scnc-fir...
# 302  https://cameroonpostline.com/as-parliament-ope...
# 304  https://cameroonpostline.com/fame-ndongo-stoke...
# 306  https://cameroonpostline.com/i-predicted-the-a...
#
# [208 rows x 3 columns]

# %%
output_clean['Site'].unique()
# Out:
# array(['Vanguard', 'Sun News', 'The Nation', 'Tribune', 'Daily Trust',
#        'Independent', 'Bareta News', 'Cameroon Post'], dtype=object)

# %% [markdown]
# ## Soup Making

# %%
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \ AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36'}

# %%
vanguard = output_clean.loc[output_clean['Site'] == 'Vanguard']
vanguard_documents_list = []

for link in vanguard['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    vanguard_documents_list.append(link_soup.find("div", class_ = "entry-content").get_text())
    
vanguard['Document'] = vanguard_documents_list

# %%
sun_news = output_clean.loc[output_clean['Site'] == 'Sun News']
sun_news_documents_list = []

for link in sun_news['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    sun_news_documents_list.append(link_soup.find("div", class_ = "content-inner").get_text())
    
sun_news['Document'] = sun_news_documents_list

# %%
the_nation = output_clean.loc[output_clean['Site'] == 'The Nation']
the_nation_documents_list = []
for link in the_nation['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    the_nation_documents_list.append(link_soup.find("div", class_ = "entry-content").get_text())

the_nation['Document'] = the_nation_documents_list

# %%
tribune = output_clean.loc[output_clean['Site'] == 'Tribune']
tribune_documents_list = []

for link in tribune['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    tribune_documents_list.append(link_soup.find("div", class_ = "entry-content clearfix").get_text())
    
tribune['Document'] = tribune_documents_list

# %%
daily_trust = output_clean.loc[output_clean['Site'] == 'Daily Trust']
daily_trust_documents_list = []

for link in vanguard['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    daily_trust_documents_list.append(link_soup.find("div", class_ = "entry-content").get_text())
    
daily_trust['Document'] = daily_trust_documents_list

# %%
independent = output_clean.loc[output_clean['Site'] == 'Independent']
independent_documents_list = []

for link in independent['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    independent_documents_list.append(link_soup.find("div", class_ = "td-post-content").get_text())
    
independent['Document'] = independent_documents_list

# %%
bareta_news = output_clean.loc[output_clean['Site'] == 'Bareta News']
bareta_news_documents_list = []

for link in bareta_news['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    bareta_news_documents_list.append(link_soup.find("div", class_ = "theiaPostSlider_preloadedSlide").get_text())
    
bareta_news['Document'] = bareta_news_documents_list

# %%
cameroon_post = output_clean.loc[output_clean['Site'] == 'Cameroon Post']
cameroon_post_documents_list = []

for link in cameroon_post['Link']: 
    link_response = requests.get(link, headers = headers)
    time.sleep(5)
    link_soup =  BeautifulSoup(link_response.content, "html.parser")
    cameroon_post_documents_list.append(link_soup.find("div", class_ = "entry-content").get_text())
    
cameroon_post['Document'] = cameroon_post_documents_list
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %% [markdown]
# ## Corpus Creation

# %%
output_clean['Document'] = pd.concat([vanguard['Document'],sun_news['Document'],the_nation['Document'],tribune['Document'],daily_trust['Document'],independent['Document'],bareta_news['Document'],cameroon_post['Document']], axis = 0)

# %%
output_clean['Document'] = output_clean['Document'].str.replace(r'\n', ' ')

# %%
output_clean.head()
# Out:
#   Search Term      Site                                               Link  \
# 0   Ambazonia  Vanguard  https://www.vanguardngr.com/2018/02/vision-amb...
# 2   Ambazonia  Vanguard  https://www.vanguardngr.com/2018/02/declared-a...
# 4   Ambazonia  Vanguard  https://www.vanguardngr.com/2018/04/france-amb...
# 6   Ambazonia  Vanguard         https://www.vanguardngr.com/tag/ambazonia/
# 8   Ambazonia  Vanguard  https://www.vanguardngr.com/tag/ambazonia-repu...
#
#                                             Document
# 0   By Emmanuel Unah & Victoria Ojeme This Insigh...
# 2   By Emmanuel Unah, Victoria Ojeme & Dotun Ibiw...
# 4   By Derric Yuh For the past three weeks, an en...
# 6   In Manyu in particular, schools cannot re-ope...
# 8    In the English speaking part of Cameroun, if...

# %%
output_clean.tail()
# Out:
#     Search Term           Site  \
# 298  Boko Haram  Cameroon Post
# 300  Boko Haram  Cameroon Post
# 302  Boko Haram  Cameroon Post
# 304  Boko Haram  Cameroon Post
# 306  Boko Haram  Cameroon Post
#
#                                                   Link  \
# 298  https://cameroonpostline.com/appointing-atanga...
# 300  https://cameroonpostline.com/released-scnc-fir...
# 302  https://cameroonpostline.com/as-parliament-ope...
# 304  https://cameroonpostline.com/fame-ndongo-stoke...
# 306  https://cameroonpostline.com/i-predicted-the-a...
#
#                                               Document
# 298    Appointing Atanga Nji, Nalova Lyonga Ministe...
# 300    Released SCNC Firebrand Warns gov’t Against ...
# 302    As Parliament Opens: House Speaker Ignores M...
# 304    Fame Ndongo Stokes Flames Of Anglophone Cris...
# 306    I Predicted The Anglophone Problem In 2008 –...

# %%
path_or_buf = 'Output_Clean.csv'
output_clean.to_csv(path_or_buf)
